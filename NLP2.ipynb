# %% [markdown]
# ## Sentiment Analysis and Topic Modeling
# Goal: Analyze user sentiment on the IMDB Movie Reviews dataset using classification and topic modeling.
#
# Key Features:
# - Feature extraction using CountVectorizer and TF-IDF
# - Word embedding generation with Word2Vec (via Gensim)
# - Supervised learning using Support Vector Machines (SVM)
# - Topic extraction with Latent Dirichlet Allocation (LDA)
# - Cross-validation with Stratified K-Fold

# %%
# !pip install numpy==1.21.2
# !pip install scipy==1.7.1
# !pip install pandas==1.3.3
# !pip install seaborn==0.11.2
# !pip install jupyter==1.0.0
# !pip install scikit-learn==1.0
# !pip install gensim==4.1.2
# !pip install python-Levenshtein==0.12.2
# Out:
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement numpy==1.21.2 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4, 1.25.0, 1.25.1, 1.25.2, 1.26.0, 1.26.1, 1.26.2, 1.26.3, 1.26.4, 2.0.0, 2.0.1, 2.0.2, 2.1.0rc1, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.2.0rc1, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4)
# ERROR: No matching distribution found for numpy==1.21.2
# ERROR: Ignored the following versions that require a different python version: 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11
# ERROR: Could not find a version that satisfies the requirement scipy==1.7.1 (from versions: 0.8.0, 0.9.0, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.12.1, 0.13.0, 0.13.1, 0.13.2, 0.13.3, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.16.0, 0.16.1, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 1.0.0, 1.0.1, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.4.0, 1.4.1, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 1.5.4, 1.6.0, 1.6.1, 1.9.0rc1, 1.9.0rc2, 1.9.0rc3, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0rc1, 1.10.0rc2, 1.10.0, 1.10.1, 1.11.0rc1, 1.11.0rc2, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.11.4, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.13.0rc1, 1.13.0, 1.13.1, 1.14.0rc1, 1.14.0rc2, 1.14.0, 1.14.1, 1.15.0rc1, 1.15.0rc2, 1.15.0, 1.15.1, 1.15.2)
# ERROR: No matching distribution found for scipy==1.7.1
# Collecting pandas==1.3.3
#   Downloading pandas-1.3.3.tar.gz (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 26.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-k2vq4at9/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-k2vq4at9/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-k2vq4at9/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 522, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-k2vq4at9/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 18, in <module>
#       ModuleNotFoundError: No module named 'numpy'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting seaborn==0.11.2
#   Obtaining dependency information for seaborn==0.11.2 from https://files.pythonhosted.org/packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.11.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.15 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from seaborn==0.11.2) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from seaborn==0.11.2) (1.13.1)
# Requirement already satisfied: pandas>=0.23 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from seaborn==0.11.2) (2.2.3)
# Requirement already satisfied: matplotlib>=2.2 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from seaborn==0.11.2) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->seaborn==0.11.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->seaborn==0.11.2) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.2) (1.16.0)
# Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# Successfully installed seaborn-0.11.2
# Requirement already satisfied: jupyter==1.0.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: notebook in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter==1.0.0) (6.5.4)
# Requirement already satisfied: qtconsole in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter==1.0.0) (5.4.2)
# Requirement already satisfied: jupyter-console in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter==1.0.0) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter==1.0.0) (6.5.4)
# Requirement already satisfied: ipykernel in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter==1.0.0) (5.5.6)
# Requirement already satisfied: ipywidgets in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter==1.0.0) (8.0.4)
# Requirement already satisfied: ipython-genutils in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (7.31.1)
# Requirement already satisfied: traitlets>=4.1.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (5.7.1)
# Requirement already satisfied: jupyter-client in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (7.4.9)
# Requirement already satisfied: tornado>=4.2 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (6.3.2)
# Requirement already satisfied: appnope in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (0.1.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipywidgets->jupyter==1.0.0) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipywidgets->jupyter==1.0.0) (3.0.5)
# Collecting ipykernel (from jupyter==1.0.0)
#   Obtaining dependency information for ipykernel from https://files.pythonhosted.org/packages/94/5c/368ae6c01c7628438358e6d337c19b05425727fbb221d2a3c4303c372f42/ipykernel-6.29.5-py3-none-any.whl.metadata
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter==1.0.0) (5.3.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter==1.0.0) (3.0.36)
# Requirement already satisfied: pygments in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter==1.0.0) (2.15.1)
# Requirement already satisfied: pyzmq>=17 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter==1.0.0) (23.2.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (1.5.6)
# Requirement already satisfied: packaging in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (23.1)
# Requirement already satisfied: psutil in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0) (5.9.0)
# Collecting pyzmq>=17 (from jupyter-console->jupyter==1.0.0)
#   Obtaining dependency information for pyzmq>=17 from https://files.pythonhosted.org/packages/22/75/774e9a4a4291864dd37a03a7bfaf46a82d61cd36c16edd33a5739ad49be3/pyzmq-26.3.0-cp311-cp311-macosx_10_15_universal2.whl.metadata
#   Downloading pyzmq-26.3.0-cp311-cp311-macosx_10_15_universal2.whl.metadata (6.2 kB)
# Requirement already satisfied: lxml in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (4.12.2)
# Requirement already satisfied: bleach in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (0.4)
# Requirement already satisfied: jinja2>=3.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0) (1.2.1)
# Requirement already satisfied: argon2-cffi in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from qtconsole->jupyter==1.0.0) (2.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0) (68.0.0)
# Requirement already satisfied: jedi>=0.16 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0) (0.18.1)
# Requirement already satisfied: decorator in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0) (0.7.5)
# Requirement already satisfied: backcall in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-client->ipykernel->jupyter==1.0.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter==1.0.0) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.2.2)
# Requirement already satisfied: fastjsonschema in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0) (4.17.3)
# Requirement already satisfied: wcwidth in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0) (0.2.5)
# Requirement already satisfied: ptyprocess in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter==1.0.0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0) (2.4)
# Requirement already satisfied: six>=1.9.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->jupyter==1.0.0) (1.16.0)
# Requirement already satisfied: webencodings in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->jupyter==1.0.0) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter==1.0.0) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.5.0)
# Requirement already satisfied: websocket-client in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (1.15.1)
# Requirement already satisfied: idna>=2.8 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.2.0)
# Requirement already satisfied: pycparser in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (2.21)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Downloading pyzmq-26.3.0-cp311-cp311-macosx_10_15_universal2.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyzmq, ipykernel
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Uninstalling pyzmq-23.2.0:
#       Successfully uninstalled pyzmq-23.2.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# Successfully installed ipykernel-6.29.5 pyzmq-26.3.0
# Collecting scikit-learn==1.0
#   Downloading scikit-learn-1.0.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 26.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [35 lines of output]
#       Partial import of sklearn during the build process.
#       <string>:128: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#       Traceback (most recent call last):
#         File "/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 149, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-bpg0u_lq/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 377, in prepare_metadata_for_build_wheel
#           self.run_setup()
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-bpg0u_lq/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 522, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-bpg0u_lq/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 319, in <module>
#         File "<string>", line 311, in setup_package
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-bpg0u_lq/overlay/lib/python3.11/site-packages/numpy/distutils/core.py", line 24, in <module>
#           from numpy.distutils.command import config, config_compiler, \
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-bpg0u_lq/overlay/lib/python3.11/site-packages/numpy/distutils/command/config.py", line 19, in <module>
#           from numpy.distutils.mingw32ccompiler import generate_manifest
#         File "/private/var/folders/_k/skzr33td47x8z7yw_wdtd92w0000gn/T/pip-build-env-bpg0u_lq/overlay/lib/python3.11/site-packages/numpy/distutils/mingw32ccompiler.py", line 28, in <module>
#           from distutils.msvccompiler import get_build_version as get_build_msvc_version
#       ModuleNotFoundError: No module named 'distutils.msvccompiler'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting gensim==4.1.2
#   Downloading gensim-4.1.2.tar.gz (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 31.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17.0 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from gensim==4.1.2) (1.26.4)
# Requirement already satisfied: scipy>=0.18.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from gensim==4.1.2) (1.13.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from gensim==4.1.2) (5.2.1)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [611 lines of output]
#       /Users/shilpysingh/anaconda3/lib/python3.11/site-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-311
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim
#       copying gensim/interfaces.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim
#       copying gensim/downloader.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim
#       copying gensim/matutils.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim
#       copying gensim/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim
#       copying gensim/utils.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim
#       copying gensim/nosy.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       copying gensim/similarities/docsim.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       copying gensim/similarities/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       copying gensim/similarities/nmslib.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       copying gensim/similarities/levenshtein.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       copying gensim/similarities/termsim.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       copying gensim/similarities/annoy.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/similarities
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_text_analysis.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_glove2word2vec.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_parsing.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_tmdiff.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_utils.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_matutils.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_word2vec.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_segmentation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_coherencemodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_miislita.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_phrases.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_dtm.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_tfidfmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_poincare.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_corpora_hashdictionary.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_ensemblelda.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/simspeed2.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_aggregation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_lee.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_big.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_translation_matrix.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/basetmtests.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_datatype.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_similarity_metrics.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_nmf.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_lda_callback.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/utils.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_corpora_dictionary.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/svd_error.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_logentropy_model.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_similarities.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_direct_confirmation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_api.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_atmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_corpora.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_indirect_confirmation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_probability_estimation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_fasttext.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_scripts.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_normmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_hdpmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/test_sharded_corpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       copying gensim/test/simspeed.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/poincare.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/basemodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/phrases.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/ensemblelda.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/_fasttext_bin.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/normmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/translation_matrix.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/logentropy_model.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/lda_worker.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fasttext.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/tfidfmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/callbacks.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/hdpmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/ldamulticore.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/lsi_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/lda_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/nmf.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/atmodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/lsi_worker.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/coherencemodel.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wikicorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/word2vec2tensor.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/package_info.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/benchmark.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/segment_wiki.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wiki_online.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wiki.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wiki_online_nodebug.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/glove2word2vec.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       copying gensim/scripts/word2vec_standalone.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/scripts
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/parsing
#       copying gensim/parsing/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/parsing
#       copying gensim/parsing/preprocessing.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/parsing
#       copying gensim/parsing/porter.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/parsing
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/direct_confirmation_measure.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/aggregation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/text_analysis.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/probability_estimation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/indirect_confirmation_measure.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/segmentation.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/topic_coherence
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/sharded_corpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/textcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/wikicorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/csvcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/opinosiscorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/__init__.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/malletcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/mmcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/ucicorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/indexedcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/lowcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/bleicorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/dictionary.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/svmlightcorpus.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/hashdictionary.py -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       running egg_info
#       writing gensim.egg-info/PKG-INFO
#       writing dependency_links to gensim.egg-info/dependency_links.txt
#       writing requirements to gensim.egg-info/requires.txt
#       writing top-level names to gensim.egg-info/top_level.txt
#       reading manifest file 'gensim.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'COPYING.LESSER'
#       warning: no files found matching 'ez_setup.py'
#       warning: no files found matching 'gensim/models/doc2vec_inner.c'
#       adding license file 'COPYING'
#       writing manifest file 'gensim.egg-info/SOURCES.txt'
#       /Users/shilpysingh/anaconda3/lib/python3.11/site-packages/setuptools/command/build_py.py:201: _Warning: Package 'gensim.test.test_data' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/shilpysingh/anaconda3/lib/python3.11/site-packages/setuptools/command/build_py.py:201: _Warning: Package 'gensim.test.test_data.DTM' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.DTM' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.DTM' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.DTM' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.DTM' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/shilpysingh/anaconda3/lib/python3.11/site-packages/setuptools/command/build_py.py:201: _Warning: Package 'gensim.test.test_data.PathLineSentences' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.PathLineSentences' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.PathLineSentences' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.PathLineSentences' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.PathLineSentences' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /Users/shilpysingh/anaconda3/lib/python3.11/site-packages/setuptools/command/build_py.py:201: _Warning: Package 'gensim.test.test_data.old_d2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_d2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_d2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
# ...
#       copying gensim/test/test_data/toy-model-pretrained.bin -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.bin -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.vec -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_lee_subcorpus.cor -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_morfessor.bin -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_vectors.pkl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v-lee-v0.12.0 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.modeldata -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.vocab -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_3.3 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_c -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py2 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3_4 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.neg_labels.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.neg_labels.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.neg_labels.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0_lockf.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn1neg.npy -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/wordsim353.tsv -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/ldaseq_3_0_1_model -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/sstats_test.txt -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/DTM
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/1.txt -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/2.txt.bz2 -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/PathLineSentences
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.1.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.2.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.3.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.4.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.1.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.2.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.3.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.4.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_1.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_1.0.1.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.4.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_d2v_models
#       creating build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.1.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.2.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.3.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.4.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.1.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.2.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.3.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.4.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_1.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_1.0.1.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.0.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.1.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.2.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.3.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.4.0.mdl -> build/lib.macosx-11.1-arm64-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/models/doc2vec_corpusfile.cpp -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/doc2vec_corpusfile.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/doc2vec_inner.cpp -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/doc2vec_inner.pxd -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/doc2vec_inner.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fast_line_sentence.h -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fasttext_corpusfile.cpp -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fasttext_corpusfile.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fasttext_inner.c -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fasttext_inner.pxd -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/fasttext_inner.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/nmf_pgd.c -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/nmf_pgd.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/stdint_wrapper.h -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/voidptr.h -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec_corpusfile.cpp -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec_corpusfile.pxd -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec_corpusfile.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec_inner.c -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec_inner.pxd -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/models/word2vec_inner.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/models
#       copying gensim/corpora/_mmreader.c -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       copying gensim/corpora/_mmreader.pyx -> build/lib.macosx-11.1-arm64-cpython-311/gensim/corpora
#       running build_ext
#       building 'gensim.models.word2vec_inner' extension
#       creating build/temp.macosx-11.1-arm64-cpython-311
#       creating build/temp.macosx-11.1-arm64-cpython-311/gensim
#       creating build/temp.macosx-11.1-arm64-cpython-311/gensim/models
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/shilpysingh/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/shilpysingh/anaconda3/include -arch arm64 -I/Users/shilpysingh/anaconda3/include/python3.11 -I/Users/shilpysingh/anaconda3/lib/python3.11/site-packages/numpy/core/include -c gensim/models/word2vec_inner.c -o build/temp.macosx-11.1-arm64-cpython-311/gensim/models/word2vec_inner.o
#       gensim/models/word2vec_inner.c:217:12: fatal error: 'longintrepr.h' file not found
#         217 |   #include "longintrepr.h"
#             |            ^~~~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gensim
#   Running setup.py clean for gensim
# Failed to build gensim
# ERROR: Could not build wheels for gensim, which is required to install pyproject.toml-based projects
# Collecting python-Levenshtein==0.12.2
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /Users/shilpysingh/anaconda3/lib/python3.11/site-packages (from python-Levenshtein==0.12.2) (68.0.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp311-cp311-macosx_11_0_arm64.whl size=74157 sha256=089b864c63f1a4c0f88dfbfa618ab3d6fa5c9e842055fe7792012a23a887b616
#   Stored in directory: /Users/shilpysingh/Library/Caches/pip/wheels/08/39/17/367da5b72aee88c27ba574660010188efcad074dc4d02060ed
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.2

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.svm import SVC
from sklearn.decomposition import LatentDirichletAllocation

from gensim.models import Word2Vec

import pandas as pd
import numpy as np
import scipy.sparse as sp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
#       2 from sklearn.model_selection import train_test_split, StratifiedKFold
#       3 from sklearn.svm import SVC
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# We begin by loading a subset of the dataset, which contains 5000 movie reviews and their associated sentiment labels (i.e., whether a review is considered positive or negative).

# %%
df_reviews = pd.read_csv("imdb_reviews.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_reviews = pd.read_csv("imdb_reviews.csv")
#
# NameError: name 'pd' is not defined

# %%
# this cell has been tagged with excluded_from_script
# it will be ignored by the autograder
df_reviews.head()
# Out:
#                                               review  \
# 0  Taran Adarsh a reputed critic praised such a d...
# 1  Worth the entertainment value of a rental, esp...
# 2  I liked Antz, but loved "A Bug's Life". The an...
# 3  This reboot is like a processed McDonald's mea...
# 4  The working title was: "Don't Spank Baby". <br...
#
#                                     processed_review sentiment
# 0  taran adarsh repute critic praise dubba movie ...  negative
# 1  worth entertainment value rental especially li...  negative
# 2  like antz love bug life animation put paid def...  positive
# 3  reboot like process mcdonald meal compare ang ...  negative
# 4  work title spank baby wayne crawford go become...  positive

# %% [markdown]
# The `review` column contains raw review texts from the original dataset. However, it's always a good idea to process and clean text data before performing analysis. As you have performed this task in Project 3, we will provide the processed reviews for you in this case. The column `processed_review` was constructed by processing and tokenizing the raw reviews, using the `preprocess_text` function from Project 3, and then joining the review tokens by a single space. From this point, you only need to focus on the `processed_review` and `sentiment` columns.

# %% [markdown]
# Next, let's look at the distribution of class labels:

# %%
# this cell has been tagged with excluded_from_script
# it will be ignored by the autograder
display(df_reviews['sentiment'].value_counts())
# Out:
# sentiment
# negative    2500
# positive    2500
# Name: count, dtype: int64

# %% [markdown]
# We see that there are 2500 positive reviews and 2500 negative reviews. In other words, our dataset is [perfectly balanced](https://i.imgflip.com/303krn.jpg).

# %% [markdown]
# ###Count Vectorizer
#
# The first feature construction task we will perform is building a term-frequency matrix. Implement the function `count_vectorizer` that uses sklearn's `CountVectorizer` API to construct the term-frequency training matrix and testing matrix, along with the feature names (i.e., the list of words corresponding to the columns in the matrices).
#
# One point to keep in mind is that `CountVectorizer` will, by default, do its own preprocessing and tokenization (see the [documentation](https://scikit-learn.org/stable/modules/feature_extraction.html#customizing-the-vectorizer-classes) for more details). As these steps have already performed, we will need to overwrite sklearn's default behaviors by specifying the following parameters:
# * `analyzer` and `tokenizer` should be `str.split`.
# * `preprocessor` should be a function that simply returns the input. We have built this function, called `dummy_fun`, for you.
#
#
#  **Notes**:
#  * Recall from the data normalization function in Part A that, with any feature construction or transformation task, we will only perform fitting on the train data, and then transform both train and test data. In other words, no fitting should be done on the test data.

# %%
def dummy_fun(x):
    return x

def count_vectorizer(reviews_train, reviews_test = None):
    """
    Compute the term-frequency matrices for train_data and test_data using CountVectorizer.

    args:
        reviews_train (pd.Series[str]) : a Series of processed reviews for training

    kwargs:
        reviews_test (pd.Series[str]) : a Series of processed reviews for testing

    return:
        Tuple(tf_train, tf_test, features):
            tf_train (scipy.sparse.csr_matrix) : TF matrix for training
            tf_test (scipy.sparse.csr_matrix) : TF matrix for testing,
                or None if reviews_test is None
            features (List[str]) : the list of words corresponding to the columns in the TF matrices
    """
    # vectorizer = CountVectorizer(analyzer=str.split, tokenizer=str.split, preprocessor=dummy_fun)
    # tf_train = vectorizer.fit_transform(reviews_train)
    # tf_test = vectorizer.transform(reviews_test) if reviews_test is not None else None
    # features = vectorizer.get_feature_names_out().tolist()
    # return tf_train, tf_test, features
    vectorizer = CountVectorizer(
        tokenizer=str.split,
        preprocessor=None,
        token_pattern=None
    )
    tf_train = vectorizer.fit_transform(reviews_train)
    tf_test = vectorizer.transform(reviews_test) if reviews_test is not None else None
    features = vectorizer.get_feature_names_out().tolist()
    return tf_train, tf_test, features
    pass

# %%
def test_count_vectorizer():
    reviews_train, reviews_test = train_test_split(df_reviews["processed_review"], random_state = 0)
    count_vec_train, count_vec_test, features = count_vectorizer(reviews_train, reviews_test)
    assert count_vec_train.shape == (3750, 27242)
    assert count_vec_test.shape == (1250, 27242)
    assert np.allclose(
        count_vec_train.sum(axis = 1)[:10].ravel().tolist()[0],
        [70, 65, 168, 77, 139, 132, 28, 139, 453, 89]
    )
    assert np.allclose(
        count_vec_test.sum(axis = 1)[:10].ravel().tolist()[0],
        [168, 60, 59, 144, 494, 135, 69, 119, 76, 68]
    )
    assert features[:10] == ['00', '000', '00015', '007', '00pm', '00s', '01', '01pm', '02', '029']
    assert features[-10:] == ['zucco', 'zucker', 'zukovic', 'zula', 'zuleika', 'zumhofe', 'zurer', 'zvezda', 'zwick', 'zylberstein']
    print("All tests passed!")

test_count_vectorizer()
# Out:
# All tests passed!

# %% [markdown]
# ### TF-IDF Vectorizer
#
# Now let's use the TF-IDF feature construction method. Implement the function `tfidf_vectorizer` that uses sklearn's `TfidfVectorizer` API to construct the TF-IDF training matrix and testing matrices, along with the feature names (i.e., the list of words corresponding to the columns in the matrices). Use the same parameter values for `analyzer`, `tokenizer` and `preprocessor` as you did in the previous question.

# %%
def tfidf_vectorizer(reviews_train, reviews_test = None):
    """
    Compute the TF-IDF matrices for train_data and test_data using TfidfVectorizer.

    args:
        reviews_train (pd.Series[str]) : a Series of processed reviews for training

    kwargs:
        reviews_test (pd.Series[str]) : a Series of processed reviews for testing

    return:
        Tuple(tf_train, tf_test, features):
            tf_train (scipy.sparse.csr_matrix) : TF-IDF matrix for training
            tf_test (scipy.sparse.csr_matrix) : TF-IDF matrix for testing,
                or None if reviews_test is None
            features (List[str]) : the list of words corresponding to the columns in the TF-IDF matrices
    """
    # vectorizer = TfidfVectorizer(analyzer=str.split, tokenizer=str.split, preprocessor=dummy_fun)
    # tf_train = vectorizer.fit_transform(reviews_train)
    # tf_test = vectorizer.transform(reviews_test) if reviews_test is not None else None
    # features = vectorizer.get_feature_names_out().tolist()
    # return tf_train, tf_test, features

    vectorizer = TfidfVectorizer(
        tokenizer=str.split,
        preprocessor=None,
        token_pattern=None
    )
    tf_train = vectorizer.fit_transform(reviews_train)
    tf_test = vectorizer.transform(reviews_test) if reviews_test is not None else None
    features = vectorizer.get_feature_names_out().tolist()
    return tf_train, tf_test, features
    pass

# %%
def test_tfidf_vectorizer():
    reviews_train, reviews_test = train_test_split(df_reviews["processed_review"], random_state = 0)
    tfidf_vec_trains, tfidf_vec_test, features = tfidf_vectorizer(reviews_train, reviews_test)
    assert tfidf_vec_trains.shape == (3750, 27242)
    assert tfidf_vec_test.shape == (1250, 27242)
    assert np.allclose(
        tfidf_vec_trains.sum(axis = 1)[:10].ravel().tolist()[0],
        [7.03658925089979, 7.417196035144321, 11.492434722367015, 6.965673648338525, 9.428219597939362, 9.425632229448961, 3.9722806270035345, 9.635230284023372, 11.779155501275017, 7.44670396016231]
    )
    assert np.allclose(
        tfidf_vec_test.sum(axis = 1)[:10].ravel().tolist()[0],
        [7.2233277330801196, 4.869804242110142, 6.249091468966529, 9.689812079503804, 11.89432945296538, 9.115185225757216, 6.798492438570971, 8.57464867777901, 7.954528809138947, 6.81383392701789]
    )
    assert features[:10] == ['00', '000', '00015', '007', '00pm', '00s', '01', '01pm', '02', '029']
    assert features[-10:] == ['zucco', 'zucker', 'zukovic', 'zula', 'zuleika', 'zumhofe', 'zurer', 'zvezda', 'zwick', 'zylberstein']
    print("All tests passed!")

test_tfidf_vectorizer()
# Out:
# All tests passed!

# %% [markdown]
# ### Predicting review sentiment
# Let's now see which feature construction method -- TF or TF-IDF -- is better for predicting review sentiments in our dataset. Our choice of learning algorithm here will be a support vector machine with Gaussian kernel (this means that it uses a different hypothesis function that can also account for non-linearly separable data). You can apply this learning algorithm by creating an instance of sklearn's [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) class, with `kernel = "rbf"` and `C = 10`.
#
# Implement the function `predict_sentiment` that takes as input the `reviews` and `sentiment` columns of our IMDB dataset and performs the following tasks:
# 1. Convert the `sentiment` column to a vector `y` of 1s and -1s: `positive` corresponds to 1 and `negative` to -1.
# 1. Perform a [stratified k-fold split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html) of the review and sentiment vectors, based on the provided `k`. Also set `shuffle` to `True` and `random_state` to the provided `seed`.
# 1. For $f$ from $1 \to k$:
#      * Let fold $f$ be the test set, and the remaining $k-1$ folds be the training set.
#      * Convert the training and testing reviews to feature matrices `X_train` and `X_test`, using either TF or TF-IDF. Which method to use is based on the function parameter `method`.
#      * Train the SVM model on `X_train, y_train` and evaluate its accuracy $a_f$ on `X_test, y_test`.
# 1. Return $a_1, a_2, \ldots, a_k$.
#
# **Notes**:
# * As a reminder, accuracy is defined as
# $$\text{Acc} = \frac{1}{n} \sum_{i=1}^n \mathbb{1}(y^{(i)} = \hat y^{(i)}).$$
# You can also use the `score` function from `SVC` to quickly compute accuracy on test data.

# %%
def predict_review_sentiment(reviews, sentiments, method, k, seed = 0):
    """
    Compute the cross-validated accuracy of SVM with either TF or TF-IDF features
    in predicting review sentiment.

    args:
        reviews (pd.Series[str]) : a Series of all processed movie reviews
        sentiments (pd.Series[str]) : a Series of movie review sentiments,
            containing either "positive" or "negative"
        method (str) : a string which is either "TF" or "TF-IDF",
            specifying which feature construction method to use
        k (int) : the number of folds in stratified k-fold split

    kwargs:
        seed (int) : the random generator seed for kfold split

    return:
        List[float] : a list of k accuracy values from evaluating a trained SVM model
            on each of the k folds, using the remaining folds as training data
    """
    y = np.where(sentiments == "positive", 1, -1)
    skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=seed)
    accuracies = []

    for train_index, test_index in skf.split(reviews, y):
        reviews_train, reviews_test = reviews.iloc[train_index], reviews.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]

        if method == "TF":
            X_train, X_test, _ = count_vectorizer(reviews_train, reviews_test)
        elif method == "TF-IDF":
            X_train, X_test, _ = tfidf_vectorizer(reviews_train, reviews_test)
        else:
            raise ValueError("Method must be 'TF' or 'TF-IDF'")

        model = SVC(kernel="rbf", C=10)
        model.fit(X_train, y_train)
        accuracies.append(model.score(X_test, y_test))

    return accuracies

    pass

# %%
def test_predict_review_sentiment():
    # prediction based on TF
    count_vec_accs = predict_review_sentiment(df_reviews["processed_review"], df_reviews["sentiment"], "TF", 10)
    assert count_vec_accs == [0.878, 0.836, 0.854, 0.824, 0.826, 0.824, 0.824, 0.85, 0.844, 0.83]

    # prediction based on TF-IDF
    tf_idf_accs = predict_review_sentiment(df_reviews["processed_review"], df_reviews["sentiment"], "TF-IDF", 10)
    assert tf_idf_accs == [0.88, 0.862, 0.85, 0.868, 0.854, 0.846, 0.864, 0.874, 0.874, 0.846]
    print("All tests passed!")
    print("Cross-validated accuracy of SVM with TF matrices", np.mean(count_vec_accs))
    print("Cross-validated accuracy of SVM with TF-IDF matrices", np.mean(tf_idf_accs))

test_predict_review_sentiment()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-d72466c02b59> in <cell line: 0>()
#      11     print("Cross-validated accuracy of SVM with TF-IDF matrices", np.mean(tf_idf_accs))
#      12
# ---> 13 test_predict_review_sentiment()
#
# <ipython-input-20-d72466c02b59> in test_predict_review_sentiment()
#       5
#       6     # prediction based on TF-IDF
# ----> 7     tf_idf_accs = predict_review_sentiment(df_reviews["processed_review"], df_reviews["sentiment"], "TF-IDF", 10)
#       8     assert tf_idf_accs == [0.88, 0.862, 0.85, 0.868, 0.854, 0.846, 0.864, 0.874, 0.874, 0.846]
#       9     print("All tests passed!")
#
# <ipython-input-19-48f101a723c6> in predict_review_sentiment(reviews, sentiments, method, k, seed)
#      35
#      36         model = SVC(kernel="rbf", C=10)
# ---> 37         model.fit(X_train, y_train)
#      38         accuracies.append(model.score(X_test, y_test))
#      39
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     256
#     257         seed = rnd.randint(np.iinfo("i").max)
# --> 258         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     259         # see comment on the other call to np.iinfo in this file
#     260
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in _sparse_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     375             self.fit_status_,
#     376             self._num_iter,
# --> 377         ) = libsvm_sparse.libsvm_sparse_train(
#     378             X.shape[1],
#     379             X.data,
#
# _libsvm_sparse.pyx in sklearn.svm._libsvm_sparse.libsvm_sparse_train()
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/_compressed.py in __init__(self, arg1, shape, dtype, copy)
#      25     """
#      26
# ---> 27     def __init__(self, arg1, shape=None, dtype=None, copy=False):
#      28         _data_matrix.__init__(self)
#      29
#
# KeyboardInterrupt:

# %% [markdown]
# We see that using TF-IDF features yields better cross-validated accuracy than using TF features (when the learning algorithm is SVM with RBF kernel and $C = 10$), although the difference in this case is not large.

# %% [markdown]
# ### Topic modeling and word distribution
# Let's now try to understand the review texts a bit more. We can treat all the reviews as a corpus and perform Latent Dirichlet Allocation to extract the corpus topics. We can also see which words are most frequent in a given topic. Implement the function `top_words_by_topic` that takes as input the `processed_reviews` column in our IMDB dataset and performs the following tasks:
#
# 1. Build a term-frequency matrix out of this column. Remember to use the same `CountVectorizer` parameters as in Q11.
# 1. Input this matrix to sklearn's `LatentDirichletAllocation`. The number of topics and random generator seed are provided as function parameters. You should specify `learning_method` as `"online"`.
# 1. In the resulting word-topic matrix, identify the most frequent `n_top_words` in each topic. These most frequent words should be sorted from lower to higher frequency.

# %%
def top_words_by_topic(reviews, n_topics = 10, n_top_words = 20, seed = 0):
    """
    Perform topic modeling on the movie review corpus and return the most frequent words in each topic.

    args:
        reviews (pd.Series[str]) : a Series of all processed movie reviews

    kwargs:
        n_topics (int) : the number of topics to model by LDA
        n_top_words (int) : the number of most frequent words to identify in each topic
        seed (int) : the random generator seed for LDA

    return:
        List[List[str]] : a nested list of words, where each of the n_topics inner lists
            contains the n_top_words most frequent words in a given topic
    """
    vectorizer = CountVectorizer(tokenizer=str.split, preprocessor=None, token_pattern=None)
    term_matrix = vectorizer.fit_transform(reviews)
    lda = LatentDirichletAllocation(n_components=n_topics, learning_method="online", random_state=seed)
    lda.fit(term_matrix)

    words = vectorizer.get_feature_names_out()
    top_words = []

    for topic in lda.components_:
        top_indices = topic.argsort()[-n_top_words:]
        top_words.append(sorted(words[i] for i in top_indices))

    return top_words
    pass

# %%
def test_top_words_by_topic():
    corpus = pd.Series([
        "I like to eat broccoli and bananas",
        "I ate a banana and spinach smoothie for breakfast",
        "Chinchillas and kittens are cute",
        "My sister adopted a kitten yesterday",
        "Look at this cute hamster munching on a piece of broccoli"
    ])
    top_words = top_words_by_topic(corpus, n_topics = 2, n_top_words = 5)
    assert top_words == [['Look', 'broccoli', 'and', 'cute', 'a'], ['I', 'eat', 'like', 'to', 'and']]

    top_words = top_words_by_topic(df_reviews["processed_review"], n_topics = 5, n_top_words = 5)
    assert top_words == [
        ['performance', 'play', 'version', 'jack', 'role'],
        ['dancer', 'paris', 'dance', 'cartoon', 'hitchcock'],
        ['make', 'like', 'one', 'film', 'movie'],
        ['film', 'father', 'world', 'american', 'war'],
        ['mad', 'sheriff', 'match', 'carmen', 'arthur']
    ]
    print("All tests passed!")

test_top_words_by_topic()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-f5a8d48ee2be> in <cell line: 0>()
#      20     print("All tests passed!")
#      21
# ---> 22 test_top_words_by_topic()
#
# <ipython-input-23-f5a8d48ee2be> in test_top_words_by_topic()
#       8     ])
#       9     top_words = top_words_by_topic(corpus, n_topics = 2, n_top_words = 5)
# ---> 10     assert top_words == [['Look', 'broccoli', 'and', 'cute', 'a'], ['I', 'eat', 'like', 'to', 'and']]
#      11
#      12     top_words = top_words_by_topic(df_reviews["processed_review"], n_topics = 5, n_top_words = 5)
#
# AssertionError:

# %% [markdown]
# ### Bonus: Word embedding and word similarity
# Finally, let's look at how we can train a word embedding model from our movie review corpus. Unfortunately, gensim's `Word2Vec` does not output reproducible results across different environments, so we will not grade this question. Instead, here we provide the implementation of the function `get_most_similar_words` that takes as input the `processed_reviews` column in our IMDB dataset, and for each input word, returns a list of `n_similar_words` top similar tokens to that word, based on the Word2Vec model. Here the tokens are ordered from lower to higher similarity values.
#
# You can see the code below and play around with different settings to better understand Word2Vec.

# %%
def find_most_similar_words(reviews, input_words, n_similar_words):
    corpus = [review.split() for review in reviews]
    model = Word2Vec(sentences = corpus, vector_size = 100, window = 5, workers = 4, min_count = 1)
    similar_words = []
    for inp_word in input_words:
        similar_words.append([w for w in sorted(model.wv.most_similar(inp_word, topn = n_similar_words), key = lambda x: x[1])])
    return similar_words

# %%
def test_find_most_similar_words():
    input_words = ["see", "good", "bad", "watch", "check"]
    most_similar_words = find_most_similar_words(df_reviews["processed_review"], input_words, 7)
    for i in range(len(input_words)):
        print(f"Words most similar to '{input_words[i]}':")
        print(most_similar_words[i])
        print()

test_find_most_similar_words()
